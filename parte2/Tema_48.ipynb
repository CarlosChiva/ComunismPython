# %% [markdown]
#                         Tema 48

# %% [markdown]
# Problema 1:

# %% [markdown]
# Definir una clase Cliente que almacene un código de cliente y un nombre.
# En la clase Cliente definir una variable de clase de tipo lista que almacene todos los clientes que tienen suspendidas sus cuentas corrientes.
# Imprimir por pantalla todos los datos de clientes y el estado que se encuentra su cuenta corriente.

# %%
class Cliente:
    suspendidos=[]
    def __init__(self,codigo,nombre):
        self.codigo=codigo
        self.nombre=nombre
    def imprimir(self):
        print("Codigo:",self.codigo)
        print("Nombre:",self.nombre)
        self.esta_suspendido()
    def esta_suspendido(self):
        if self.codigo in Cliente.suspendidos:
            print("Esta suspendido")
        else:
            print("No esta suspendido")
        print("_____________________________")
    def suspender(self):
        Cliente.suspendidos.append(self.codigo)

# %%
cliente1=Cliente(1,"Juan")
cliente2=Cliente(2,"Ana")
cliente3=Cliente(3,"Diego")
cliente4=Cliente(4,"Pedro")
cliente3.suspender()
cliente4.suspender()
cliente1.imprimir()
cliente2.imprimir()
cliente3.imprimir()
cliente4.imprimir()
print(Cliente.suspendidos)
# Out:
# Codigo: 1
# Nombre: Juan
# No esta suspendido
# _____________________________
# Codigo: 2
# Nombre: Ana
# No esta suspendido
# _____________________________
# Codigo: 3
# Nombre: Diego
# Esta suspendido
# _____________________________
# Codigo: 4
# Nombre: Pedro
# Esta suspendido
# _____________________________
# [3, 4]

# %% [markdown]
# Problema propuesto

# %% [markdown]
# Plantear una clase llamada Jugador.
# Definir en la clase Jugador los atributos nombre y puntaje, y los métodos __init__, imprimir y pasar_tiempo (que debe reducir en uno la variable de clase).
# Declarar dentro de la clase Jugador una variable de clase que indique cuantos minutos falta para el fin de juego (iniciarla con el valor 30)
# Definir en el bloque principal dos objetos de la clase Jugador.
# Reducir dicha variable hasta llegar a cero.

# %%
class Jugador:
    tiempo=30
    def __init__(self, nombre, puntaje):
        self.nombre=nombre
        self.puntaje=puntaje
    def imprimir(self):
        print("Nombre:",self.nombre)
        print("Puntaje:",self.puntaje)
        print("Fin de juego en",Jugador.tiempo,"minutos")
    def pasar_minuto(self):
        Jugador.tiempo=Jugador.tiempo-1

# %%
jugador1=Jugador("Juan",100)
jugador2=Jugador("Ana",50)
while Jugador.tiempo>0:
    jugador1.imprimir()
    jugador2.imprimir()
    jugador1.pasar_minuto()
# Out:
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 30 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 30 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 29 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 29 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 28 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 28 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 27 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 27 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 26 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 26 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 25 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 25 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 24 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 24 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 23 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 23 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 22 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 22 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 21 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 21 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 20 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 20 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 19 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 19 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 18 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 18 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 17 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 17 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 16 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 16 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 15 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 15 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 14 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 14 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 13 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 13 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 12 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 12 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 11 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 11 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 10 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 10 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 9 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 9 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 8 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 8 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 7 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 7 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 6 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 6 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 5 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 5 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 4 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 4 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 3 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 3 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 2 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 2 minutos
# Nombre: Juan
# Puntaje: 100
# Fin de juego en 1 minutos
# Nombre: Ana
# Puntaje: 50
# Fin de juego en 1 minutos
